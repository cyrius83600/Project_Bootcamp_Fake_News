# %%
import pandas as pd

# %%
def GetMappingLiarDataset(files_name):
    dfs = []
    for file_name in files_name:
        df_liar = pd.read_csv(file_name,delimiter='\t')
        df_liar_mapping = df_liar.iloc[:,[1,2]]
        df_liar_mapping.columns=['IsFakeNews','text']
        df_liar_mapping['label'] = df_liar_mapping.IsFakeNews.apply(lambda x: 0 if x=='false' else 1)
        df_liar_mapping.drop('IsFakeNews',axis=1,inplace=True)
        dfs.append(df_liar_mapping)
    df_test = pd.concat([dfs[1],dfs[2]],axis=0)
    return (dfs[0],df_test)

# %%
df_train, df_test = GetMappingLiarDataset(['train.tsv','test.tsv','valid.tsv'])
df_test
# Out:
# /tmp/ipykernel_25500/3144580796.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_liar_mapping['label'] = df_liar_mapping.IsFakeNews.apply(lambda x: 0 if x=='false' else 1)
# /tmp/ipykernel_25500/3144580796.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_liar_mapping.drop('IsFakeNews',axis=1,inplace=True)
# /tmp/ipykernel_25500/3144580796.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_liar_mapping['label'] = df_liar_mapping.IsFakeNews.apply(lambda x: 0 if x=='false' else 1)
# /tmp/ipykernel_25500/3144580796.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_liar_mapping.drop('IsFakeNews',axis=1,inplace=True)
# /tmp/ipykernel_25500/3144580796.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_liar_mapping['label'] = df_liar_mapping.IsFakeNews.apply(lambda x: 0 if x=='false' else 1)
# /tmp/ipykernel_25500/3144580796.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_liar_mapping.drop('IsFakeNews',axis=1,inplace=True)
#                                                    text  label
# 0     Wisconsin is on pace to double the number of l...      0
# 1     Says John McCain has done nothing to help the ...      0
# 2     Suzanne Bonamici supports a plan that will cut...      1
# 3     When asked by a reporter whether hes at the ce...      1
# 4     Over the past five years the federal governmen...      1
# ...                                                 ...    ...
# 1278  For the first time in more than a decade, impo...      1
# 1279  Says Donald Trump has bankrupted his companies...      1
# 1280  John McCain and George Bush have "absolutely n...      1
# 1281  A new poll shows 62 percent support the presid...      0
# 1282  No one claims the report vindicating New Jerse...      1
#
# [2549 rows x 2 columns]
